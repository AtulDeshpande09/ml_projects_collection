# %%
import matplotlib.pyplot as plt

# %%
algorithms = ['SVM','Logistic Regression' , 'Random Forest','CNN']
accuracy = [0.928,.9221,0.9586, 0.989899]

# %%
plt.figure(figsize = (12,6))
plt.bar(algorithms,accuracy)
plt.xlabel('Algorithms')
plt.ylabel('Accuracy')
plt.show()
